# %% [markdown]
# 1.Who developed Python Programming Language?
#
# ->Guido van Rossum developed Python Programming Language.
#
#
# 2.Which type of Programming does Python support?
#
# ->Python supports multiple programming paradigms, including object-oriented, imperative, functional, and procedural programming styles.
#
#
# 3.Is Python case sensitive when dealing with identifiers?
#
# ->Yes, Python is case sensitive when dealing with identifiers.
#
#
# 4.What is the correct extension of the Python file?
#
# ->The correct extension of the Python file is ".py".
#
#
# 5.Is Python code compiled or interpreted?
#
# ->Python code is interpreted, not compiled.
#
#
# 6.Name a few blocks of code used to define in Python language?
#
# ->Blocks of code used to define in Python language are:
# Functions: Defined using the def keyword.
# Classes: Defined using the class keyword.
# Modules: A file containing Python code.
# Packages: A collection of modules.
#
#
# 7.State a character used to give single-line comments in Python?
#
# ->The character used to give single-line comments in Python is the hash symbol (#).
#
#
# 8.Mention functions which can help us to find the version of python that we are currently working on?
#
# ->Functions to find the version of Python that we are currently working on are:
# sys.version: Returns the version of the Python interpreter as a string.
# sys.version_info: Returns a tuple of five integers that identify the Python version.
#
#
# 9.Python supports the creation of anonymous functions at runtime, using a construct called "lambda"
#
#
# 10.What does pip stand for python?
#
# ->pip stands for "Pip Installs Packages".
#
#
# 11.Mention a few built-in functions in python?
#
# ->Built-in functions in Python include:
# print(): Used to print the specified message to the screen.
# len(): Used to find the length of an object.
# str(): Used to convert a specified object into a string.
# int(): Used to convert a specified object into an integer.
# float(): Used to convert a specified object into a float.
#
#
# 12.What is the maximum possible length of an identifier in Python?
#
# ->The maximum possible length of an identifier in Python is 127 characters.
#
#
# 13.What are the benefits of using Python?
#
# ->The benefits of using Python include:
# Easy-to-read syntax.
# Cross-platform compatibility.
# Strong community support.
# Extensive standard library.
#
#
# 14.How is memory managed in Python?
#
# ->Memory management in Python is handled by a private heap space. Python's memory manager handles memory allocation and deallocation.
#
#
# 15.How to install Python on Windows and set path variables?
#
# ->To install Python on Windows and set path variables:
# Download the Python installer from the official website.
# Run the installer and follow the on-screen instructions.
# During the installation process, check the box that says "Add Python to PATH".
# Once the installation is complete, open a command prompt and type python --version to verify the installation.
#
#
# 16.Is indentation required in python?
#
# ->Indentation is required in Python. It is used to define the scope of the code block. Python uses indentation to define the boundaries of the code block instead of using braces like in other programming languages.
